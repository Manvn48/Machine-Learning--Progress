# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import utils

# %%
features = np.array([1,2,3,5,6,7])
labels = np.array([155,197,244,356,107,448])

print(features)
print(labels)
# Out:
# [1 2 3 5 6 7]
# [155 197 244 356 107 448]

# %%
utils.plot_points(features, labels)

# %%
def square_trick(price_per_room ,num_rooms , predicted_price , base_price):
    predicted_price = base_price + price_per_room*num_rooms
    price_per_rooms += learning_rate*num_rooms(price-predicted_price)
    base_price += learning_rate*(price-predicted_price)
    return price_per_room, base_price

# %%
import random
random.seed(0)

def linear_regression(features , labels , learning_rate=0.01 , epochs=1000 ):
    price_per_rooms = random.random()
    base_price = random.random()
    for epoch in range(epochs):
        if True:
